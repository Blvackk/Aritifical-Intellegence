# %%
import os
import nltk
# nltk.download()

# %%
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in
humans and animals. With Artificial Intelligence, machines perform functions such a
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of huma
It is probably the fastest-growing development in the World of technology and innov
AI could solve major challenges and crisis situations.'''

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in\nhumans and animals. With Artificial Intelligence, machines perform functions such a\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of huma\nIt is probably the fastest-growing development in the World of technology and innov\nAI could solve major challenges and crisis situations.'

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
ai_tokens=word_tokenize(AI)

# %%
print(ai_tokens)
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'a', 'problem-solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'huma', 'It', 'is', 'probably', 'the', 'fastest-growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innov', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']

# %%
len(ai_tokens)
# Out:
# 59

# %%
from nltk.tokenize import sent_tokenize

# %%
ai_sent=sent_tokenize(AI)

# %%
print(ai_sent)
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.', 'This is in\nhumans and animals.', 'With Artificial Intelligence, machines perform functions such a\nproblem-solving.', 'Most noteworthy, Artificial Intelligence is the simulation of huma\nIt is probably the fastest-growing development in the World of technology and innov\nAI could solve major challenges and crisis situations.']

# %%
len(ai_sent)
# Out:
# 4

# %%
from nltk.tokenize import blankline_tokenize
ai_blank=blankline_tokenize(AI)
print(ai_blank)
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in\nhumans and animals. With Artificial Intelligence, machines perform functions such a\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of huma\nIt is probably the fastest-growing development in the World of technology and innov\nAI could solve major challenges and crisis situations.']

# %%
len(ai_blank)
# Out:
# 1

# %%
from nltk.tokenize import WhitespaceTokenizer
wt=WhitespaceTokenizer().tokenize(AI)

# %%
print(wt)
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines.', 'This', 'is', 'in', 'humans', 'and', 'animals.', 'With', 'Artificial', 'Intelligence,', 'machines', 'perform', 'functions', 'such', 'a', 'problem-solving.', 'Most', 'noteworthy,', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'huma', 'It', 'is', 'probably', 'the', 'fastest-growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innov', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations.']

# %%
len(wt)
# Out:
# 53

# %%
s='Good apple cost $3.88 in hydrabad. Please buy two of them.Thanks.'
print(s)
# Out:
# Good apple cost $3.88 in hydrabad. Please buy two of them.Thanks.

# %%
from nltk.tokenize import wordpunct_tokenize
wt=wordpunct_tokenize(s)
print(wt)
print(len(wt))
# Out:
# ['Good', 'apple', 'cost', '$', '3', '.', '88', 'in', 'hydrabad', '.', 'Please', 'buy', 'two', 'of', 'them', '.', 'Thanks', '.']
# 18

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in\nhumans and animals. With Artificial Intelligence, machines perform functions such a\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of huma\nIt is probably the fastest-growing development in the World of technology and innov\nAI could solve major challenges and crisis situations.'

# %%
wf=wordpunct_tokenize(AI)

# %%
print(wf)
print(len(wf))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'a', 'problem', '-', 'solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'huma', 'It', 'is', 'probably', 'the', 'fastest', '-', 'growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innov', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']
# 63

# %%
from nltk.util import bigrams,trigrams,ngrams

# %%
string ='generative ai & asgentic ai is autoate the industry & more focus on every domain'
quotes_tokens = nltk.word_tokenize(string)
quotes_tokens
# Out:
# ['generative',
#  'ai',
#  '&',
#  'asgentic',
#  'ai',
#  'is',
#  'autoate',
#  'the',
#  'industry',
#  '&',
#  'more',
#  'focus',
#  'on',
#  'every',
#  'domain']

# %%
string
# Out:
# 'generative ai & asgentic ai is autoate the industry & more focus on every domain'

# %%
quotes_tokens
# Out:
# ['generative',
#  'ai',
#  '&',
#  'asgentic',
#  'ai',
#  'is',
#  'autoate',
#  'the',
#  'industry',
#  '&',
#  'more',
#  'focus',
#  'on',
#  'every',
#  'domain']

# %%
len(quotes_tokens)
# Out:
# 15

# %%
quotes_bigrams = list(nltk.bigrams(quotes_tokens))
quotes_bigrams
# Out:
# [('generative', 'ai'),
#  ('ai', '&'),
#  ('&', 'asgentic'),
#  ('asgentic', 'ai'),
#  ('ai', 'is'),
#  ('is', 'autoate'),
#  ('autoate', 'the'),
#  ('the', 'industry'),
#  ('industry', '&'),
#  ('&', 'more'),
#  ('more', 'focus'),
#  ('focus', 'on'),
#  ('on', 'every'),
#  ('every', 'domain')]

# %%
quotes_trigrams = list(nltk.trigrams(quotes_tokens))
quotes_trigrams
# Out:
# [('generative', 'ai', '&'),
#  ('ai', '&', 'asgentic'),
#  ('&', 'asgentic', 'ai'),
#  ('asgentic', 'ai', 'is'),
#  ('ai', 'is', 'autoate'),
#  ('is', 'autoate', 'the'),
#  ('autoate', 'the', 'industry'),
#  ('the', 'industry', '&'),
#  ('industry', '&', 'more'),
#  ('&', 'more', 'focus'),
#  ('more', 'focus', 'on'),
#  ('focus', 'on', 'every'),
#  ('on', 'every', 'domain')]

# %%
quotes_ngrams = list(nltk.ngrams(quotes_tokens))
quotes_ngrams
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 quotes_ngrams = list(nltk.ngrams(quotes_tokens))
#       2 quotes_ngrams
#
# TypeError: ngrams() missing 1 required positional argument: 'n'

# %%
quotes_ngrams = list(nltk.ngrams(quotes_tokens,5))
quotes_ngrams

# IT HAS GIVEN N-GRAMS OF LENGTH 5

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem('affection')

# %%
pst.stem('playing')

# %%
pst.stem('maximum')

# %%
words_to_stem =['give','giving','given','gave']

for words in words_to_stem:
    print(words+ ' : ' +pst.stem(words))

# %%
words_to_stem =['give','giving','given','gaved','thinking','maximun']
# I am giving these different words to stem , using stemmer we get the output

for words in words_to_stem:
    print(words+':'+pst.stem(words))

# %%
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()

for words in words_to_stem:
    print(words+':'+lst.stem(words))

# %%
from nltk.stem import SnowballStemmer
sbst =SnowballStemmer('english')

for words in words_to_stem:
    print(words+ ':'+sbst.stem(words))

# %%
stemmer =SnowballStemmer("german") #Choose a Language
>>> stemmer.stem("Autobahnen") #Stem a word

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_len =  WordNetLemmatizer()

# %%
words_to_stem

# %%
for words in words_to_stem:
    print(words+':'+word_len.lemmatize(words))

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')

# %%
len(stopwords.words('english'))

# %%
stopwords.words('spanish')

# %%
len(stopwords.words('spanish'))

# %%
# We will see how to work in POS using NLTK library


sent = 'my name is Pratik Lagishetty'
sent_tokens= word_tokenize(sent)
sent_tokens

#First we will tokenizze using word_tokenize & then we will use pos_tag on all of the tokens

# %%
for token in sent_tokens:
    print(nltk.pos_tag([token]))

# %%
from nltk import ne_chunk

# %%
NE_sent ='The US president stays in the WHITEHOUSE'

# %%
NE_tokens = word_tokenize(NE_sent)
#after tokenize need to add the pos tags
NE_tokens

# %%
NE_tags = nltk.pos_tag(NE_tokens)
NE_tags

# %%
NE_NER = ne_chunk(NE_tokens)
print(NE_NER)

# %% [markdown]
# # NLG (NATURAL LANGUAGE GENERATION)

# %%
pip install wordcloud

# %%
#Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# create a list of words
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# %%
#Create the wordcloud object
wordcloud =WordCloud(width=420,height=200,margin=2,background_color ='black', colormap='Accent',mode='RGBA').generate(text)

# %%
#Display the generated Image
plt.imshow(wordcloud,interpolation='quadric')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
