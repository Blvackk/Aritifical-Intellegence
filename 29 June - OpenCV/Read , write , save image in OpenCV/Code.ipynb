# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\prati\Downloads\COLLEGE ID.jpeg")

# %%
input
# Out:
# array([[[179, 174, 171],
#         [179, 174, 171],
#         [178, 173, 170],
#         ...,
#         [153, 164, 168],
#         [151, 162, 166],
#         [149, 160, 164]],
#
#        [[179, 174, 171],
#         [178, 173, 170],
#         [178, 173, 170],
#         ...,
#         [153, 164, 168],
#         [152, 163, 167],
#         [150, 161, 165]],
#
#        [[178, 173, 170],
#         [178, 173, 170],
#         [178, 173, 170],
#         ...,
#         [154, 165, 169],
#         [153, 164, 168],
#         [152, 163, 167]],
#
#        ...,
#
#        [[ 22,  18,  17],
#         [ 21,  17,  16],
#         [ 21,  17,  16],
#         ...,
#         [120, 124, 135],
#         [120, 124, 135],
#         [120, 124, 135]],
#
#        [[ 23,  19,  18],
#         [ 22,  18,  17],
#         [ 22,  18,  17],
#         ...,
#         [120, 124, 135],
#         [120, 124, 135],
#         [120, 124, 135]],
#
#        [[ 24,  20,  19],
#         [ 23,  19,  18],
#         [ 23,  19,  18],
#         ...,
#         [120, 124, 135],
#         [120, 124, 135],
#         [120, 124, 135]]], shape=(1599, 899, 3), dtype=uint8)

# %%
cv2.imshow('College Id',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print("Height of Image:", int(input.shape[0]),'pixels')
print('Width of Image:', int(input.shape[1]),'pixels')
# Out:
# Height of Image: 1599 pixels
# Width of Image: 899 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\prati\\NareshIT'
